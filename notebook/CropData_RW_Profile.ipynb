# %% [markdown]
# # HarvestStat Data Profiling - Rwanda

# %%
import glob
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import retreive_fdw_data, save_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import product_name_mapping, FDW_PD_CaliSeasonYear, FDW_PD_MergeCropProductionSystem
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# %%
# Set loading parameters ------------------------ #
country_name = 'Rwanda'
country_iso2 = 'RW'
use_api_data = False
requires_authentication = False
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'epsg:32735' # Rwanda
fn_shapes = sorted(glob.glob(f"../data/shapefile/fewsnet/{country_iso2}_Admin?_????.shp"))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
# PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# Load FDW data -------------------------------- #
df = retreive_fdw_data(country_name, country_iso2, use_api_data, requires_authentication)
# ----------------------------------------------- #
# Out:
# Data is loaded from the local file.
# ../data/crop_raw_data/adm_crop_data_raw_RW.csv is loaded.

# %%
# Manual Pre-processing before Sweeping --------- #
# 1. Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'
# ----------------------------------------------- #
df = df[np.isfinite(df.value)]
df_admin1=df[df['admin_2'].isna()]
df = df.dropna(subset=['admin_2'])

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df, area_priority="Area Planted")
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([RW_Admin2_2006], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 8,409
# Removed 11 "Missing Value" points
# 2,205/2,205 "Area Planted" points are retained.
# 4,032/4,038 "Quantity Produced" points are retained.
# 2,161/2,166 "Yield" points are retained.
# Current data points: 8,398
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 2008 - 2017
# 38 grain types are found: Avocado (Hass), Avocado (unspecified), Banana (unspecified), Beans (mixed), Beet, Bush bean, Cabbage (Unspecified), Carrots, Cassava, Cassava (non-bitter), Cauliflowers, Celery, Cereal Crops (Mixed), Champignon, Cooking Banana (unspecified), Eggplant, Green bean (fresh), Green pea, Groundnuts (In Shell), Leeks, Maize Grain (Fresh), Maize Grain (White), Okras (Fresh), Pea (unspecified), Pole bean, Potato (Irish), Rice (Paddy), Sorghum, Soybean (unspecified), Spinach, Squash (Unspecified), Sugarcane (for sugar), Sunflower Seed, Sweet Potatoes, Taro/Cocoyam (Unspecified), Tomato, Wheat Grain, Yams
# 3 seasons are found: Season B (06-01), Season A (02-01), Season C (09-01)
# 1 crop production system are found: none
# Data sources include:
# [1] Ministry of Agriculture and Animal Resources, Rwanda --- Crop Assessment, Rwanda
# [2] NISR, Rwanda --- Agricultural Survey, Rwanda
# Administrative-1 fnids: 0
# Administrative-2 fnids: 30
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name                  Season A Season B Season C
#
# Avocado (Hass)                   0.0%     0.0%     0.0%
# Avocado (unspecified)            0.1%     0.1%     0.0%
# Banana (unspecified)            10.3%     8.7%     0.0%
# Beans (mixed)                    0.8%     0.8%     0.0%
# Beet                             0.0%     0.0%     0.0%
# Bush bean                        1.2%     0.9%     0.0%
# Cabbage (Unspecified)            0.1%     0.1%     0.0%
# Carrots                          0.0%     0.0%     0.0%
# Cassava                         10.4%    11.2%     0.0%
# Cassava (non-bitter)             0.3%     0.2%     0.0%
# Cauliflowers                     0.0%     0.0%     0.0%
# Celery                           0.0%     0.0%     0.0%
# Cereal Crops (Mixed)             0.0%     0.2%     0.0%
# Champignon                       0.0%     0.0%     0.0%
# Cooking Banana (unspecified)     3.7%     3.5%     0.0%
# Eggplant                         0.0%     0.1%     0.0%
# Green bean (fresh)               0.1%     0.1%     0.0%
# Green pea                        0.0%     0.0%     0.0%
# Groundnuts (In Shell)            0.1%     0.1%     0.0%
# Leeks                            0.0%     0.0%     0.0%
# Maize Grain (Fresh)              0.1%     0.1%     0.0%
# Maize Grain (White)              3.9%     1.1%     0.0%
# Okras (Fresh)                    0.0%     0.0%     0.0%
# Pea (unspecified)                0.2%     0.2%     0.0%
# Pole bean                        1.2%     0.6%     0.0%
# Potato (Irish)                  10.5%     6.8%     0.2%
# Rice (Paddy)                     0.3%     0.3%     0.0%
# Sorghum                          0.4%     2.1%     0.0%
# Soybean (unspecified)            0.2%     0.2%     0.0%
# Spinach                          0.0%     0.0%     0.0%
# Squash (Unspecified)             0.1%     0.0%     0.0%
# Sugarcane (for sugar)            0.1%     0.1%     0.0%
# Sunflower Seed                   0.0%     0.0%     0.0%
# Sweet Potatoes                   7.5%     7.9%     0.0%
# Taro/Cocoyam (Unspecified)       0.1%     0.3%     0.0%
# Tomato                           0.1%     0.1%     0.0%
# Wheat Grain                      0.1%     0.3%     0.0%
# Yams                             1.0%     0.9%     0.0%
#
# - Crop calendar ------------------------------- #
#                   product season_name planting_month harvest_month
# 0          Avocado (Hass)    Season B          06-01         06-01
# 1          Avocado (Hass)    Season A          02-01         02-01
# 2   Avocado (unspecified)    Season A          02-01         02-01
# 3   Avocado (unspecified)    Season B          06-01         06-01
# 4    Banana (unspecified)    Season B          06-01         06-01
# ..                    ...         ...            ...           ...
# 76                 Tomato    Season B          06-01         06-01
# 77            Wheat Grain    Season B          06-01         06-01
# 78            Wheat Grain    Season A          02-01         02-01
# 79                   Yams    Season A          02-01         02-01
# 80                   Yams    Season B          06-01         06-01
#
# [81 rows x 4 columns]
# - Recorded years per season ------------------- #
# Season B: 10 years (2008-2017) (missing: 5 years)
# Season A: 10 years (2008-2017) (missing: 5 years)
# Season C: 1 years (2013-2013) (missing: 0 years)
#
# - Number of "Quantity Produced" data points --- #
# RW2006A2: 4,032 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Avocado (Hass)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      21/30    26/30
# ----------------------------------------------- #
# Crop type: Avocado (unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Banana (unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# 2009                        NaN    27/30
# 2010                      28/30    28/30
# 2011                        NaN      NaN
# 2012                      28/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Beans (mixed)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2009                        NaN    27/30
# 2010                      28/30    28/30
# 2011                        NaN      NaN
# 2012                      26/30      NaN
# ----------------------------------------------- #
# Crop type: Beet
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                       7/30     9/30
# ----------------------------------------------- #
# Crop type: Bush bean
# ----------------------------------------------- #
# season_name            Season A Season B Season C
# crop_production_system     none     none     none
# fnid_short               2006A2   2006A2   2006A2
# year
# 2008                      30/30    30/30      NaN
# 2009                        NaN      NaN      NaN
# 2010                        NaN      NaN      NaN
# 2011                        NaN      NaN      NaN
# 2012                        NaN      NaN      NaN
# 2013                       5/30     5/30     4/30
# 2014                        NaN      NaN      NaN
# 2015                        NaN      NaN      NaN
# 2016                        NaN      NaN      NaN
# 2017                      30/30    30/30      NaN
# ----------------------------------------------- #
# Crop type: Cabbage (Unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Carrots
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      26/30    28/30
# ----------------------------------------------- #
# Crop type: Cassava
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      29/30    30/30
# 2009                        NaN    27/30
# 2010                      27/30    28/30
# 2011                        NaN      NaN
# 2012                      28/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Cassava (non-bitter)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Cauliflowers
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      13/30    13/30
# ----------------------------------------------- #
# Crop type: Celery
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      18/30    17/30
# ----------------------------------------------- #
# Crop type: Cereal Crops (Mixed)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2013                       2/30     2/30
# ----------------------------------------------- #
# Crop type: Champignon
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      29/30    29/30
# ----------------------------------------------- #
# Crop type: Cooking Banana (unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# 2009                        NaN      NaN
# 2010                        NaN      NaN
# 2011                        NaN      NaN
# 2012                        NaN      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Eggplant
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Green bean (fresh)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Green pea
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      29/30    29/30
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      22/30    25/30
# 2009                        NaN    19/30
# 2010                      17/30    17/30
# 2011                        NaN      NaN
# 2012                      18/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      21/30    16/30
# ----------------------------------------------- #
# Crop type: Leeks
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      21/30    19/30
# ----------------------------------------------- #
# Crop type: Maize Grain (Fresh)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Maize Grain (White)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# 2009                        NaN    27/30
# 2010                      28/30    28/30
# 2011                        NaN      NaN
# 2012                      28/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Okras (Fresh)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                       2/30     4/30
# ----------------------------------------------- #
# Crop type: Pea (unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B Season C
# crop_production_system     none     none     none
# fnid_short               2006A2   2006A2   2006A2
# year
# 2008                      30/30    30/30      NaN
# 2009                        NaN    26/30      NaN
# 2010                      27/30    25/30      NaN
# 2011                        NaN      NaN      NaN
# 2012                      28/30      NaN      NaN
# 2013                       5/30     5/30     3/30
# 2014                        NaN      NaN      NaN
# 2015                        NaN      NaN      NaN
# 2016                        NaN      NaN      NaN
# 2017                      28/30    29/30      NaN
# ----------------------------------------------- #
# Crop type: Pole bean
# ----------------------------------------------- #
# season_name            Season A Season B Season C
# crop_production_system     none     none     none
# fnid_short               2006A2   2006A2   2006A2
# year
# 2008                      30/30    29/30      NaN
# 2009                        NaN      NaN      NaN
# 2010                        NaN      NaN      NaN
# 2011                        NaN      NaN      NaN
# 2012                      28/30      NaN      NaN
# 2013                       5/30     5/30     3/30
# 2014                        NaN      NaN      NaN
# 2015                        NaN      NaN      NaN
# 2016                        NaN      NaN      NaN
# 2017                      30/30    30/30      NaN
# ----------------------------------------------- #
# Crop type: Potato (Irish)
# ----------------------------------------------- #
# season_name            Season A Season B Season C
# crop_production_system     none     none     none
# fnid_short               2006A2   2006A2   2006A2
# year
# 2008                      30/30    30/30      NaN
# 2009                        NaN    27/30      NaN
# 2010                      28/30    28/30      NaN
# 2011                        NaN      NaN      NaN
# 2012                      28/30      NaN      NaN
# 2013                       5/30     5/30     4/30
# 2014                        NaN      NaN      NaN
# 2015                        NaN      NaN      NaN
# 2016                        NaN      NaN      NaN
# 2017                      29/30    29/30      NaN
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      24/30    23/30
# 2009                        NaN    15/30
# 2010                      17/30    17/30
# 2011                        NaN      NaN
# 2012                       8/30      NaN
# 2013                        NaN      NaN
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      16/30    17/30
# ----------------------------------------------- #
# Crop type: Sorghum
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      28/30    30/30
# 2009                        NaN    27/30
# 2010                       9/30    28/30
# 2011                        NaN      NaN
# 2012                      14/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      23/30    27/30
# ----------------------------------------------- #
# Crop type: Soybean (unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B Season C
# crop_production_system     none     none     none
# fnid_short               2006A2   2006A2   2006A2
# year
# 2008                      28/30    29/30      NaN
# 2009                        NaN    19/30      NaN
# 2010                      28/30    23/30      NaN
# 2011                        NaN      NaN      NaN
# 2012                      25/30      NaN      NaN
# 2013                       5/30     5/30     2/30
# 2014                        NaN      NaN      NaN
# 2015                        NaN      NaN      NaN
# 2016                        NaN      NaN      NaN
# 2017                      30/30    30/30      NaN
# ----------------------------------------------- #
# Crop type: Spinach
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      21/30    22/30
# ----------------------------------------------- #
# Crop type: Squash (Unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Sugarcane (for sugar)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      29/30    29/30
# ----------------------------------------------- #
# Crop type: Sunflower Seed
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      22/30    26/30
# ----------------------------------------------- #
# Crop type: Sweet Potatoes
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# 2009                        NaN    27/30
# 2010                      28/30    28/30
# 2011                        NaN      NaN
# 2012                      28/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# Crop type: Taro/Cocoyam (Unspecified)
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    30/30
# 2009                        NaN      NaN
# 2010                        NaN      NaN
# 2011                        NaN      NaN
# 2012                       9/30      NaN
# ----------------------------------------------- #
# Crop type: Tomato
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      30/30    29/30
# ----------------------------------------------- #
# Crop type: Wheat Grain
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      24/30    24/30
# 2009                        NaN    14/30
# 2010                      11/30    13/30
# 2011                        NaN      NaN
# 2012                       8/30      NaN
# 2013                        NaN      NaN
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      11/30    13/30
# ----------------------------------------------- #
# Crop type: Yams
# ----------------------------------------------- #
# season_name            Season A Season B
# crop_production_system     none     none
# fnid_short               2006A2   2006A2
# year
# 2008                      21/30    25/30
# 2009                        NaN    27/30
# 2010                      24/30    26/30
# 2011                        NaN      NaN
# 2012                      28/30      NaN
# 2013                       5/30     5/30
# 2014                        NaN      NaN
# 2015                        NaN      NaN
# 2016                        NaN      NaN
# 2017                      30/30    30/30
# ----------------------------------------------- #
# ../figures/RW_admin_shapes.png is saved.

# %% [markdown]
# - Rwanda crop seasonal calendar
#
# <img src="https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-rwanda.png?itok=6LEEa9FZ" width=900><br>
#
# <img src="https://ipad.fas.usda.gov/rssiws/al/crop_calendar/images/eafrica_rw_calendar.png" width=900>
#
# - comparison of boundaries</br>
#
# <img src="../figures/RW_admin_shapes.png" width=900>
#
# - In Rwanda, basd on the FEWS NET data, there were three times of changes in administrative units. We will use the 2006 administrative units
#
# | Year  | Admin-1  | # units  | Admin-2  | # units | Admin-3  | # units |
# | :---: | :----:   | :----:   | :----:   | :---:   | :----:   | :---:   |
# | 1959	 | RW1959A1 | 10	| nan	| 0	| nan	| 0	|
# | 1992	 | RW1992A1 | 11	| nan	| 0	| nan	| 0	|
# | 1996	 | RW1996A1 | 12	| nan	| 0	| nan	| 0	|
# | 2006	 | RW2006A1 | 5	| RW2006A2	| 30	| nan	| 0	|

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = RW_Admin2_2006.copy().to_crs('epsg:32735')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area_new, prod_new = FDW_PD_Compiling(df, shape_used)
# ----------------------------------------------- #

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new
# ----------------------------------------------- #

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = crop_new.T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]
# ----------------------------------------------- #

# Remove certain crops -------------------------- #
# Remove some crops only 2008 data and similar crop type exists (Donghoon)
product_remove = ['Avocado (Hass)', 'Cassava (non-bitter)', 'Maize Grain (Fresh)']
stack = stack[~stack['product'].isin(product_remove)]
# ----------------------------------------------- #

# Final Processing ------------------------------ #
# Product name mapping
stack = product_name_mapping(stack, list_except=None)
# Calibration of crop calendar using External Season Calendar (ESC)
esc = pd.read_csv('../data/crop_calendar/external_season_calendar.csv')
stack, link_ratio = FDW_PD_CaliSeasonYear(stack, esc, link_ratio=None)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #

#define a QC flag field
# 0 = no flag
# 1 = outlier
stack['QC_flag'] = 0

# Save data
fn_out = '../data/crop/adm_crop_production_RW.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
# Out:
# All [country, season_name] are in the external season calendar.
# ../data/crop/adm_crop_production_RW.csv is saved.

# %% [markdown]
# # Visualization of production data

# %%
# Bar chart of national crop production
country_iso, country_name = 'RW', 'Rwanda'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name   in ['Season A','Season B','Season C']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/RW_bar_natgrainprod_Season A.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/RW_bar_natgrainprod_Season B.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/RW_bar_natgrainprod_Season C.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name = 'RW', 'Rwanda'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
     ['Cassava','Season A'],
     ['Cassava','Season B'],
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
