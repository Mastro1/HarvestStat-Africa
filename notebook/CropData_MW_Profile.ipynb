# %% [markdown]
# # HarvestStat Data Profiling - Malawi

# %%
import glob
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import retreive_fdw_data, save_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import product_name_mapping, FDW_PD_CaliSeasonYear, FDW_PD_MergeCropProductionSystem
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# %%
# Set loading parameters ------------------------ #
country_name = 'Malawi'
country_iso2 = 'MW'
use_api_data = False
requires_authentication = False
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:32736' # Malawi
fn_shapes = sorted(glob.glob(f"../data/shapefile/fewsnet/{country_iso2}_Admin?_????.shp"))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
# PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# Load FDW data -------------------------------- #
df = retreive_fdw_data(country_name, country_iso2, use_api_data, requires_authentication)
# ----------------------------------------------- #
# Out:
# Data is loaded from the local file.
# ../data/crop_raw_data/adm_crop_data_raw_MW.csv is loaded.

# %%
# Manual Pre-processing before Sweeping --------- #

# 1. Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'

# 2. Manual setting
# a) Add admin names to reporting units
admin_level = 'admin_3'
reporting_unit = df.loc[df['fnid'].map(lambda x: x[6] != 'A'), 'fnid'].unique()
df.loc[df.fnid.isin(reporting_unit),admin_level] = df.loc[df.fnid.isin(reporting_unit), 'locality_name'].map(lambda x: x.split(' ')[0])

# b) remove minor crops for which there is only a few years of data
df = df.loc[~(np.isin(df['product'],['Pineapple (unspecified)', 'Pigeon pea (hybrid)', 'Papaya (unspecified)', 
                                    'Orange (unspecified)', 'Mango (unspecified)', 'Macadamia (unspecified)']))]

#c) remove the "estate" and "Estate (PS)" production systems
df = df.loc[~(np.isin(df['crop_production_system'],['Estate (PS)','estate']))]

#d) rename crops
df.loc[(df['product']=='Pigeon pea (Unspecified)'),'product'] = 'Pigeon Peas'
df.loc[(df['product']=='Coffee (unspecified)'),'product'] = 'Coffee (Unspecified)'

#e) drop seasons that are not the main season with only intermediate amounts of data
df = df.loc[~((df['product']=='Rice (Paddy)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Bambara groundnut')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Cassava')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Sesame Seed')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Sunflower Seed')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Soybean (unspecified)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Millet (Finger)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Groundnuts (In Shell)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Maize Grain (White)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Tobacco (Burley)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Cotton (Unspecified)')&(df['season_name']=='Winter'))]
df = df.loc[~((df['product']=='Cowpeas (Mixed)')&(df['season_name']=='Main'))]
df = df.loc[~((df['product']=='Wheat Grain')&(df['season_name']=='Main'))]

#f) drop some of the subcrops to keep the dominant type
df = df.loc[~((df['product']=='Tobacco (Flue-Cured)'))]
df = df.loc[~((df['product']=='Tobacco (NDDF)'))]
df = df.loc[~((df['product']=='Tobacco (SDDF)'))]
df = df.loc[~(df['product']=='Tobacco (Oriental)')]

#drop 2019 for Burley Tobacco as this value needs to be corrected
df = df.loc[~((df['product']=='Tobacco (Burley)')&(df['season_year']=='Main 2019'))]
# ----------------------------------------------- #

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df, area_priority="Area Planted")
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([MW_Admin2_1971, MW_Admin2_1998, MW_Admin2_2003, MW_Admin2_2018], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 35,654
# 12,139/12,139 "Area Planted" points are retained.
# 11,764/11,764 "Quantity Produced" points are retained.
# 11,751/11,751 "Yield" points are retained.
# Current data points: 35,654
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1983 - 2023
# 33 grain types are found: Bambara groundnut, Banana (unspecified), Bean (Hyacinth), Beans (Pinto), Beans (mixed), Cabbage (Unspecified), Cassava, Chick Peas, Chili pepper (Unspecified), Coffee (Unspecified), Cotton (Unspecified), Cowpea (unspecified), Field Peas, Garlic (fresh), Groundnuts (In Shell), Maize Grain (White), Millet, Millet (Finger), Millet (Pearl), Onions, Paprika (unspecified), Pigeon Peas, Potato (Irish), Rice (Paddy), Sesame Seed, Sorghum, Soybean (unspecified), Sunflower Seed, Sweet Potatoes, Tobacco (Burley), Tomato, Velvet bean, Wheat Grain
# 3 seasons are found: Annual (10-01), Winter (10-01), Main (04-01)
# 3 crop production system are found: All (PS), irrigated, Rainfed (PS)
# Data sources include:
# [1] Ministry of Agriculture, Irrigation and Water Development, Malawi --- Alt_DS_Annual Production Estimate Survey, Malawi
# [2] Ministry of Agriculture, Irrigation and Water Development, Malawi --- Annual Production Estimate Survey, Malawi
# [3] Ministry of Agriculture, Irrigation and Water Development, Malawi --- FAO Summary spreadsheet, Malawi
# [4] Ministry of Agriculture, Irrigation and Water Development, Malawi --- FEWS NET Agro-Maps, Malawi
# [5] National Statistical Office, Malawi --- National Census of Agriculture and Livestock, Malawi
# Administrative-1 fnids: 0
# Administrative-2 fnids: 104
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name                Annual   Main Winter
#
# Bambara groundnut            0.0%   0.0%   0.0%
# Banana (unspecified)         0.0%   1.3%   0.0%
# Bean (Hyacinth)              0.0%   0.0%   0.0%
# Beans (Pinto)                0.0%   0.0%   0.0%
# Beans (mixed)                0.2%   0.6%   0.2%
# Cabbage (Unspecified)        0.0%   0.0%   0.0%
# Cassava                      5.8%  25.5%   0.0%
# Chick Peas                   0.0%   0.0%   0.0%
# Chili pepper (Unspecified)   0.0%   0.2%   0.0%
# Coffee (Unspecified)         0.0%   3.1%   0.0%
# Cotton (Unspecified)         0.0%   0.6%   0.0%
# Cowpea (unspecified)         0.0%   0.2%   0.0%
# Field Peas                   0.0%   0.0%   0.0%
# Garlic (fresh)               0.0%   0.0%   0.0%
# Groundnuts (In Shell)        0.5%   1.8%   0.0%
# Maize Grain (White)          4.5%  24.5%   0.0%
# Millet                       0.0%   0.0%   0.0%
# Millet (Finger)              0.0%   0.2%   0.0%
# Millet (Pearl)               0.0%   0.0%   0.0%
# Onions                       0.0%   0.0%   0.1%
# Paprika (unspecified)        0.0%   1.7%   0.0%
# Pigeon Peas                  0.0%   1.4%   0.0%
# Potato (Irish)               0.0%   2.5%   1.9%
# Rice (Paddy)                 0.2%   0.8%   0.0%
# Sesame Seed                  0.0%   0.0%   0.0%
# Sorghum                      0.0%   0.5%   0.0%
# Soybean (unspecified)        0.3%   0.5%   0.0%
# Sunflower Seed               0.0%   0.1%   0.0%
# Sweet Potatoes               0.0%  14.9%   4.9%
# Tobacco (Burley)             0.0%   0.6%   0.0%
# Tomato                       0.0%   0.0%   0.1%
# Velvet bean                  0.0%   0.1%   0.0%
# Wheat Grain                  0.0%   0.0%   0.1%
#
# - Crop calendar ------------------------------- #
#                        product season_name planting_month harvest_month
# 0            Bambara groundnut        Main          04-01         04-01
# 1         Banana (unspecified)        Main          04-01         04-01
# 2              Bean (Hyacinth)        Main          04-01         04-01
# 3                Beans (Pinto)      Winter          10-01         10-01
# 4                Beans (Pinto)        Main          04-01         04-01
# 5                Beans (mixed)        Main          04-01         04-01
# 6                Beans (mixed)      Annual          10-01         10-01
# 7                Beans (mixed)      Winter          10-01         10-01
# 8        Cabbage (Unspecified)        Main          04-01         04-01
# 9        Cabbage (Unspecified)      Winter          10-01         10-01
# 10                     Cassava      Annual          10-01         10-01
# 11                     Cassava        Main          04-01         04-01
# 12                  Chick Peas        Main          04-01         04-01
# 13  Chili pepper (Unspecified)        Main          04-01         04-01
# 14        Coffee (Unspecified)        Main          04-01         04-01
# 15        Cotton (Unspecified)        Main          04-01         04-01
# 16        Cowpea (unspecified)      Winter          10-01         10-01
# 17        Cowpea (unspecified)        Main          04-01         04-01
# 18                  Field Peas      Winter          10-01         10-01
# 19                  Field Peas        Main          04-01         04-01
# 20              Garlic (fresh)      Winter          10-01         10-01
# 21              Garlic (fresh)        Main          04-01         04-01
# 22       Groundnuts (In Shell)        Main          04-01         04-01
# 23       Groundnuts (In Shell)      Annual          10-01         10-01
# 24         Maize Grain (White)        Main          04-01         04-01
# 25         Maize Grain (White)      Annual          10-01         10-01
# 26                      Millet        Main          04-01         04-01
# 27             Millet (Finger)        Main          04-01         04-01
# 28              Millet (Pearl)        Main          04-01         04-01
# 29                      Onions        Main          04-01         04-01
# 30                      Onions      Winter          10-01         10-01
# 31       Paprika (unspecified)        Main          04-01         04-01
# 32       Paprika (unspecified)      Winter          10-01         10-01
# 33                 Pigeon Peas      Winter          10-01         10-01
# 34                 Pigeon Peas        Main          04-01         04-01
# 35              Potato (Irish)      Winter          10-01         10-01
# 36              Potato (Irish)        Main          04-01         04-01
# 37                Rice (Paddy)      Annual          10-01         10-01
# 38                Rice (Paddy)        Main          04-01         04-01
# 39                 Sesame Seed        Main          04-01         04-01
# 40                     Sorghum        Main          04-01         04-01
# 41       Soybean (unspecified)        Main          04-01         04-01
# 42       Soybean (unspecified)      Annual          10-01         10-01
# 43              Sunflower Seed        Main          04-01         04-01
# 44              Sweet Potatoes        Main          04-01         04-01
# 45              Sweet Potatoes      Winter          10-01         10-01
# 46            Tobacco (Burley)        Main          04-01         04-01
# 47                      Tomato      Winter          10-01         10-01
# 48                      Tomato        Main          04-01         04-01
# 49                 Velvet bean        Main          04-01         04-01
# 50                 Wheat Grain      Winter          10-01         10-01
# - Recorded years per season ------------------- #
# Annual: 6 years (2018-2023) (missing: 0 years)
# Winter: 15 years (2006-2020) (missing: 0 years)
# Main: 38 years (1983-2020) (missing: 0 years)
#
# - Number of "Quantity Produced" data points --- #
# MW1971A2: 1,522 data points are found.
# MW1998A2: 640 data points are found.
# MW2003A2: 7,693 data points are found.
# MW2018A2: 1,909 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Bambara groundnut
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                          22/28    NaN       NaN
# 2005                          20/28    NaN       NaN
# 2006                          26/28    NaN       NaN
# 2007                          27/28    NaN       NaN
# 2008                          27/28    NaN       NaN
# 2009                          26/28    NaN       NaN
# 2010                          28/28    NaN       NaN
# 2011                          28/28    NaN       NaN
# 2012                          28/28    NaN       NaN
# 2013                          27/28    NaN       NaN
# 2014                          28/28    NaN       NaN
# 2015                          28/28    NaN       NaN
# 2016                          27/28    NaN       NaN
# 2017                          26/28    NaN       NaN
# 2018                            NaN  23/32      1/32
# 2019                            NaN  24/32       NaN
# 2020                            NaN  23/32       NaN
# ----------------------------------------------- #
# Crop type: Banana (unspecified)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   2003A2 2018A2
# year
# 2005                          24/28    NaN
# 2006                           3/28    NaN
# 2007                            NaN    NaN
# 2008                           1/28    NaN
# 2009                           2/28    NaN
# 2010                           6/28    NaN
# 2011                           6/28    NaN
# 2012                           5/28    NaN
# 2013                           6/28    NaN
# 2014                           6/28    NaN
# 2015                           4/28    NaN
# 2016                           4/28    NaN
# 2017                           4/28    NaN
# 2018                            NaN    NaN
# 2019                            NaN   6/32
# 2020                            NaN   5/32
# ----------------------------------------------- #
# Crop type: Bean (Hyacinth)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                          12/28    NaN       NaN
# 2005                          10/28    NaN       NaN
# 2006                          14/28    NaN       NaN
# 2007                          13/28    NaN       NaN
# 2008                          13/28    NaN       NaN
# 2009                          12/28    NaN       NaN
# 2010                          12/28    NaN       NaN
# 2011                          13/28    NaN       NaN
# 2012                          13/28    NaN       NaN
# 2013                          13/28    NaN       NaN
# 2014                          14/28    NaN       NaN
# 2015                          14/28    NaN       NaN
# 2016                          13/28    NaN       NaN
# 2017                          14/28    NaN       NaN
# 2018                            NaN  13/32      1/32
# 2019                            NaN  14/32       NaN
# 2020                            NaN  10/32       NaN
# ----------------------------------------------- #
# Crop type: Beans (Pinto)
# ----------------------------------------------- #
# season_name                    Main                     Winter
# crop_production_system Rainfed (PS)        irrigated irrigated
# fnid_short                   2003A2 2018A2    2018A2    2018A2
# year
# 2004                           9/28    NaN       NaN       NaN
# 2005                           7/28    NaN       NaN       NaN
# 2006                           9/28    NaN       NaN       NaN
# 2007                           9/28    NaN       NaN       NaN
# 2008                           9/28    NaN       NaN       NaN
# 2009                           9/28    NaN       NaN       NaN
# 2010                           9/28    NaN       NaN       NaN
# 2011                           9/28    NaN       NaN       NaN
# 2012                           9/28    NaN       NaN       NaN
# 2013                           9/28    NaN       NaN       NaN
# 2014                           9/28    NaN       NaN       NaN
# 2015                           9/28    NaN       NaN       NaN
# 2016                           9/28    NaN       NaN       NaN
# 2017                          10/28    NaN       NaN       NaN
# 2018                            NaN   9/32      1/32       NaN
# 2019                            NaN   9/32       NaN       NaN
# 2020                            NaN   2/32       NaN      2/32
# ----------------------------------------------- #
# Crop type: Beans (mixed)
# ----------------------------------------------- #
# season_name              Annual         Main           Winter
# crop_production_system All (PS) Rainfed (PS)        irrigated
# fnid_short               2018A2       2003A2 2018A2    2003A2 2018A2
# year
# 2004                        NaN        23/28    NaN       NaN    NaN
# 2005                        NaN        24/28    NaN       NaN    NaN
# 2006                        NaN        24/28    NaN     25/28    NaN
# 2007                        NaN        22/28    NaN     23/28    NaN
# 2008                        NaN        22/28    NaN     22/28    NaN
# 2009                        NaN        22/28    NaN     27/28    NaN
# 2010                        NaN        23/28    NaN     26/28    NaN
# 2011                        NaN        22/28    NaN     27/28    NaN
# 2012                        NaN        22/28    NaN     26/28    NaN
# 2013                        NaN        22/28    NaN     27/28    NaN
# 2014                        NaN        22/28    NaN     27/28    NaN
# 2015                        NaN        22/28    NaN     26/28    NaN
# 2016                        NaN        23/28    NaN     26/28    NaN
# 2017                        NaN        20/28    NaN     22/28    NaN
# 2018                        NaN          NaN    NaN       NaN    NaN
# 2019                       5/32          NaN  18/32       NaN  20/32
# 2020                       9/32          NaN  17/32       NaN  20/32
# 2021                      28/32          NaN    NaN       NaN    NaN
# 2022                      27/32          NaN    NaN       NaN    NaN
# 2023                      20/32          NaN    NaN       NaN    NaN
# ----------------------------------------------- #
# Crop type: Cabbage (Unspecified)
# ----------------------------------------------- #
# season_name                    Main           Winter
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2003A2 2018A2
# year
# 2017                           4/28    NaN      4/28    NaN
# 2018                            NaN    NaN       NaN    NaN
# 2019                            NaN   4/32       NaN   4/32
# ----------------------------------------------- #
# Crop type: Cassava
# ----------------------------------------------- #
# season_name              Annual         Main
# crop_production_system All (PS) Rainfed (PS)
# fnid_short               2018A2       1971A2 1998A2 2003A2 2018A2
# year
# 1983                        NaN        19/24   1/27    NaN    NaN
# 1984                        NaN        20/24   1/27    NaN    NaN
# 1985                        NaN        20/24   1/27    NaN    NaN
# 1986                        NaN        20/24   1/27    NaN    NaN
# 1987                        NaN        20/24   1/27    NaN    NaN
# 1988                        NaN        20/24   2/27    NaN    NaN
# 1989                        NaN        20/24   2/27    NaN    NaN
# 1990                        NaN        20/24   2/27    NaN    NaN
# 1991                        NaN        19/24   2/27    NaN    NaN
# 1992                        NaN        21/24   2/27    NaN    NaN
# 1993                        NaN        21/24   2/27    NaN    NaN
# 1994                        NaN        21/24   2/27    NaN    NaN
# 1995                        NaN        21/24   2/27    NaN    NaN
# 1996                        NaN        21/24   2/27    NaN    NaN
# 1997                        NaN        20/24   2/27    NaN    NaN
# 1998                        NaN          NaN  23/27    NaN    NaN
# 1999                        NaN          NaN  23/27    NaN    NaN
# 2000                        NaN          NaN  23/27    NaN    NaN
# 2001                        NaN          NaN  23/27    NaN    NaN
# 2002                        NaN          NaN  25/27    NaN    NaN
# 2003                        NaN          NaN    NaN  25/28    NaN
# 2004                        NaN          NaN    NaN  26/28    NaN
# 2005                        NaN          NaN    NaN  26/28    NaN
# 2006                        NaN          NaN    NaN  28/28    NaN
# 2007                        NaN          NaN    NaN  27/28    NaN
# 2008                        NaN          NaN    NaN  28/28    NaN
# 2009                        NaN          NaN    NaN  28/28    NaN
# 2010                        NaN          NaN    NaN  28/28    NaN
# 2011                        NaN          NaN    NaN  28/28    NaN
# 2012                        NaN          NaN    NaN  28/28    NaN
# 2013                        NaN          NaN    NaN  28/28    NaN
# 2014                        NaN          NaN    NaN  28/28    NaN
# 2015                        NaN          NaN    NaN  28/28    NaN
# 2016                        NaN          NaN    NaN  26/28    NaN
# 2017                        NaN          NaN    NaN  26/28    NaN
# 2018                        NaN          NaN    NaN    NaN  24/32
# 2019                       4/32          NaN    NaN    NaN  24/32
# 2020                       6/32          NaN    NaN    NaN  21/32
# 2021                      28/32          NaN    NaN    NaN    NaN
# 2022                      28/32          NaN    NaN    NaN    NaN
# 2023                      20/32          NaN    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Chick Peas
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                           2/28    NaN       NaN
# 2005                           1/28    NaN       NaN
# 2006                           2/28    NaN       NaN
# 2007                           2/28    NaN       NaN
# 2008                           2/28    NaN       NaN
# 2009                           1/28    NaN       NaN
# 2010                           2/28    NaN       NaN
# 2011                           2/28    NaN       NaN
# 2012                           2/28    NaN       NaN
# 2013                           2/28    NaN       NaN
# 2014                           2/28    NaN       NaN
# 2015                           2/28    NaN       NaN
# 2016                           2/28    NaN       NaN
# 2017                           3/28    NaN       NaN
# 2018                            NaN   2/32      1/32
# 2019                            NaN   2/32       NaN
# 2020                            NaN   2/32       NaN
# ----------------------------------------------- #
# Crop type: Chili pepper (Unspecified)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                          11/28    NaN       NaN
# 2005                          11/28    NaN       NaN
# 2006                          11/28    NaN       NaN
# 2007                          12/28    NaN       NaN
# 2008                          13/28    NaN       NaN
# 2009                          12/28    NaN       NaN
# 2010                          14/28    NaN       NaN
# 2011                          13/28    NaN       NaN
# 2012                          15/28    NaN       NaN
# 2013                          15/28    NaN       NaN
# 2014                          13/28    NaN       NaN
# 2015                          12/28    NaN       NaN
# 2016                          10/28    NaN       NaN
# 2017                          12/28    NaN       NaN
# 2018                            NaN  12/32      1/32
# 2019                            NaN  11/32       NaN
# 2020                            NaN  12/32       NaN
# ----------------------------------------------- #
# Crop type: Coffee (Unspecified)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   2003A2 2018A2
# year
# 2004                           4/28    NaN
# 2005                           5/28    NaN
# 2006                           5/28    NaN
# 2007                            NaN    NaN
# 2008                           3/28    NaN
# 2009                           4/28    NaN
# 2010                           1/28    NaN
# 2011                           5/28    NaN
# 2012                           6/28    NaN
# 2013                           5/28    NaN
# 2014                           5/28    NaN
# 2015                           4/28    NaN
# 2016                           4/28    NaN
# 2017                           4/28    NaN
# 2018                            NaN   3/32
# 2019                            NaN   2/32
# 2020                            NaN   3/32
# ----------------------------------------------- #
# Crop type: Cotton (Unspecified)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   1971A2 1998A2 2003A2 2018A2
# year
# 1983                          16/24   1/27    NaN    NaN
# 1984                          16/24   1/27    NaN    NaN
# 1985                          16/24   1/27    NaN    NaN
# 1986                          16/24   1/27    NaN    NaN
# 1987                          16/24   1/27    NaN    NaN
# 1988                          16/24   2/27    NaN    NaN
# 1989                          16/24   2/27    NaN    NaN
# 1990                          16/24   2/27    NaN    NaN
# 1991                          15/24   1/27    NaN    NaN
# 1992                          16/24   2/27    NaN    NaN
# 1993                          16/24   2/27    NaN    NaN
# 1994                          16/24   2/27    NaN    NaN
# 1995                          17/24   2/27    NaN    NaN
# 1996                          18/24   2/27    NaN    NaN
# 1997                          17/24   2/27    NaN    NaN
# 1998                            NaN  20/27    NaN    NaN
# 1999                            NaN  20/27    NaN    NaN
# 2000                            NaN  18/27    NaN    NaN
# 2001                            NaN  18/27    NaN    NaN
# 2002                            NaN  18/27    NaN    NaN
# 2003                            NaN    NaN  19/28    NaN
# 2004                            NaN    NaN  24/28    NaN
# 2005                            NaN    NaN  22/28    NaN
# 2006                            NaN    NaN  24/28    NaN
# 2007                            NaN    NaN  23/28    NaN
# 2008                            NaN    NaN  25/28    NaN
# 2009                            NaN    NaN  24/28    NaN
# 2010                            NaN    NaN  20/28    NaN
# 2011                            NaN    NaN  21/28    NaN
# 2012                            NaN    NaN  26/28    NaN
# 2013                            NaN    NaN  26/28    NaN
# 2014                            NaN    NaN  25/28    NaN
# 2015                            NaN    NaN  25/28    NaN
# 2016                            NaN    NaN  23/28    NaN
# 2017                            NaN    NaN  20/28    NaN
# 2018                            NaN    NaN    NaN  19/32
# 2019                            NaN    NaN    NaN  19/32
# 2020                            NaN    NaN    NaN  14/32
# ----------------------------------------------- #
# Crop type: Cowpea (unspecified)
# ----------------------------------------------- #
# season_name                    Main                     Winter
# crop_production_system Rainfed (PS)        irrigated irrigated
# fnid_short                   2003A2 2018A2    2018A2    2003A2 2018A2
# year
# 2004                          21/28    NaN       NaN       NaN    NaN
# 2005                          21/28    NaN       NaN       NaN    NaN
# 2006                          27/28    NaN       NaN      2/28    NaN
# 2007                          27/28    NaN       NaN      2/28    NaN
# 2008                          27/28    NaN       NaN      3/28    NaN
# 2009                          28/28    NaN       NaN      3/28    NaN
# 2010                          28/28    NaN       NaN      3/28    NaN
# 2011                          28/28    NaN       NaN      4/28    NaN
# 2012                          28/28    NaN       NaN      4/28    NaN
# 2013                          28/28    NaN       NaN      3/28    NaN
# 2014                          28/28    NaN       NaN      3/28    NaN
# 2015                          28/28    NaN       NaN      3/28    NaN
# 2016                          27/28    NaN       NaN      3/28    NaN
# 2017                          26/28    NaN       NaN      3/28    NaN
# 2018                            NaN  23/32      1/32       NaN   3/32
# 2019                            NaN  24/32       NaN       NaN   3/32
# 2020                            NaN  23/32       NaN       NaN   3/32
# ----------------------------------------------- #
# Crop type: Field Peas
# ----------------------------------------------- #
# season_name                    Main           Winter
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2003A2 2018A2
# year
# 2004                           4/28    NaN       NaN    NaN
# 2005                           3/28    NaN       NaN    NaN
# 2006                           6/28    NaN      2/28    NaN
# 2007                           6/28    NaN      2/28    NaN
# 2008                           7/28    NaN      1/28    NaN
# 2009                           6/28    NaN      1/28    NaN
# 2010                           8/28    NaN      3/28    NaN
# 2011                           9/28    NaN      3/28    NaN
# 2012                           8/28    NaN      3/28    NaN
# 2013                           7/28    NaN      3/28    NaN
# 2014                           8/28    NaN      3/28    NaN
# 2015                           8/28    NaN      3/28    NaN
# 2016                           8/28    NaN      3/28    NaN
# 2017                           7/28    NaN      4/28    NaN
# 2018                            NaN   8/32       NaN   3/32
# 2019                            NaN   9/32       NaN   4/32
# 2020                            NaN   7/32       NaN   3/32
# ----------------------------------------------- #
# Crop type: Garlic (fresh)
# ----------------------------------------------- #
# season_name                    Main    Winter
# crop_production_system Rainfed (PS) irrigated
# fnid_short                   2003A2    2003A2
# year
# 2017                           1/28      1/28
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name              Annual         Main
# crop_production_system All (PS) Rainfed (PS)                      irrigated
# fnid_short               2018A2       1971A2 1998A2 2003A2 2018A2    2018A2
# year
# 1983                        NaN        19/24   1/27    NaN    NaN       NaN
# 1984                        NaN        20/24   1/27    NaN    NaN       NaN
# 1985                        NaN        20/24   1/27    NaN    NaN       NaN
# 1986                        NaN        20/24   1/27    NaN    NaN       NaN
# 1987                        NaN        20/24   1/27    NaN    NaN       NaN
# 1988                        NaN        19/24   2/27    NaN    NaN       NaN
# 1989                        NaN        20/24   2/27    NaN    NaN       NaN
# 1990                        NaN        20/24   2/27    NaN    NaN       NaN
# 1991                        NaN        18/24   2/27    NaN    NaN       NaN
# 1992                        NaN        19/24   2/27    NaN    NaN       NaN
# 1993                        NaN        20/24   2/27    NaN    NaN       NaN
# 1994                        NaN        20/24   2/27    NaN    NaN       NaN
# 1995                        NaN        20/24   2/27    NaN    NaN       NaN
# 1996                        NaN        20/24   2/27    NaN    NaN       NaN
# 1997                        NaN        20/24   2/27    NaN    NaN       NaN
# 1998                        NaN          NaN  22/27    NaN    NaN       NaN
# 1999                        NaN          NaN  22/27    NaN    NaN       NaN
# 2000                        NaN          NaN  22/27    NaN    NaN       NaN
# 2001                        NaN          NaN  22/27    NaN    NaN       NaN
# 2002                        NaN          NaN  24/27    NaN    NaN       NaN
# 2003                        NaN          NaN    NaN  24/28    NaN       NaN
# 2004                        NaN          NaN    NaN  27/28    NaN       NaN
# 2005                        NaN          NaN    NaN  27/28    NaN       NaN
# 2006                        NaN          NaN    NaN  27/28    NaN       NaN
# 2007                        NaN          NaN    NaN  27/28    NaN       NaN
# 2008                        NaN          NaN    NaN  27/28    NaN       NaN
# 2009                        NaN          NaN    NaN  27/28    NaN       NaN
# 2010                        NaN          NaN    NaN  27/28    NaN       NaN
# 2011                        NaN          NaN    NaN  27/28    NaN       NaN
# 2012                        NaN          NaN    NaN  27/28    NaN       NaN
# 2013                        NaN          NaN    NaN  27/28    NaN       NaN
# 2014                        NaN          NaN    NaN  27/28    NaN       NaN
# 2015                        NaN          NaN    NaN  26/28    NaN       NaN
# 2016                        NaN          NaN    NaN  26/28    NaN       NaN
# 2017                        NaN          NaN    NaN  27/28    NaN       NaN
# 2018                        NaN          NaN    NaN    NaN  16/32      1/32
# 2019                       8/32          NaN    NaN    NaN  21/32       NaN
# 2020                       8/32          NaN    NaN    NaN  20/32       NaN
# 2021                      28/32          NaN    NaN    NaN    NaN       NaN
# 2022                      28/32          NaN    NaN    NaN    NaN       NaN
# 2023                      19/32          NaN    NaN    NaN    NaN       NaN
# ----------------------------------------------- #
# Crop type: Maize Grain (White)
# ----------------------------------------------- #
# season_name              Annual         Main
# crop_production_system All (PS) Rainfed (PS)                      irrigated
# fnid_short               2018A2       1971A2 1998A2 2003A2 2018A2    2018A2
# year
# 1983                        NaN         2/24    NaN    NaN    NaN       NaN
# 1984                        NaN        21/24   1/27    NaN    NaN       NaN
# 1985                        NaN        22/24   1/27    NaN    NaN       NaN
# 1986                        NaN        22/24   1/27    NaN    NaN       NaN
# 1987                        NaN        22/24   1/27    NaN    NaN       NaN
# 1988                        NaN        20/24   2/27    NaN    NaN       NaN
# 1989                        NaN        21/24   2/27    NaN    NaN       NaN
# 1990                        NaN        22/24   2/27    NaN    NaN       NaN
# 1991                        NaN        20/24   2/27    NaN    NaN       NaN
# 1992                        NaN        22/24   2/27    NaN    NaN       NaN
# 1993                        NaN        21/24   2/27    NaN    NaN       NaN
# 1994                        NaN        22/24   2/27    NaN    NaN       NaN
# 1995                        NaN        22/24   2/27    NaN    NaN       NaN
# 1996                        NaN        22/24   2/27    NaN    NaN       NaN
# 1997                        NaN        22/24   2/27    NaN    NaN       NaN
# 1998                        NaN          NaN  24/27    NaN    NaN       NaN
# 1999                        NaN          NaN  25/27    NaN    NaN       NaN
# 2000                        NaN          NaN  25/27    NaN    NaN       NaN
# 2001                        NaN          NaN  24/27    NaN    NaN       NaN
# 2002                        NaN          NaN  24/27    NaN    NaN       NaN
# 2003                        NaN          NaN    NaN  27/28    NaN       NaN
# 2004                        NaN          NaN    NaN  27/28    NaN       NaN
# 2005                        NaN          NaN    NaN  28/28    NaN       NaN
# 2006                        NaN          NaN    NaN  28/28    NaN       NaN
# 2007                        NaN          NaN    NaN  28/28    NaN       NaN
# 2008                        NaN          NaN    NaN  28/28    NaN       NaN
# 2009                        NaN          NaN    NaN  28/28    NaN       NaN
# 2010                        NaN          NaN    NaN  28/28    NaN       NaN
# 2011                        NaN          NaN    NaN  28/28    NaN       NaN
# 2012                        NaN          NaN    NaN  28/28    NaN       NaN
# 2013                        NaN          NaN    NaN  28/28    NaN       NaN
# 2014                        NaN          NaN    NaN  28/28    NaN       NaN
# 2015                        NaN          NaN    NaN  28/28    NaN       NaN
# 2016                        NaN          NaN    NaN  28/28    NaN       NaN
# 2017                        NaN          NaN    NaN  28/28    NaN       NaN
# 2018                       4/32          NaN    NaN    NaN  24/32      1/32
# 2019                       5/32          NaN    NaN    NaN  23/32       NaN
# 2020                       7/32          NaN    NaN    NaN  23/32       NaN
# 2021                      28/32          NaN    NaN    NaN    NaN       NaN
# 2022                      28/32          NaN    NaN    NaN    NaN       NaN
# 2023                      28/32          NaN    NaN    NaN    NaN       NaN
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   1971A2 1998A2 2003A2 2018A2
# year
# 1983                           3/24    NaN    NaN    NaN
# 1984                           2/24    NaN    NaN    NaN
# 1985                           3/24    NaN    NaN    NaN
# 1986                           2/24    NaN    NaN    NaN
# 1987                           3/24    NaN    NaN    NaN
# 1988                           3/24    NaN    NaN    NaN
# 1989                           3/24    NaN    NaN    NaN
# 1990                           3/24    NaN    NaN    NaN
# 1991                           3/24    NaN    NaN    NaN
# 1992                           3/24    NaN    NaN    NaN
# 1993                           4/24    NaN    NaN    NaN
# 1994                           4/24    NaN    NaN    NaN
# 1995                           4/24    NaN    NaN    NaN
# 1996                           4/24   1/27    NaN    NaN
# 1997                           8/24   2/27    NaN    NaN
# 1998                            NaN  10/27    NaN    NaN
# 1999                            NaN  12/27    NaN    NaN
# 2000                            NaN  12/27    NaN    NaN
# 2001                            NaN  12/27    NaN    NaN
# 2002                            NaN  12/27    NaN    NaN
# 2003                            NaN    NaN  11/28    NaN
# 2004                            NaN    NaN    NaN    NaN
# 2005                            NaN    NaN   1/28    NaN
# 2006                            NaN    NaN    NaN    NaN
# 2007                            NaN    NaN    NaN    NaN
# 2008                            NaN    NaN   1/28    NaN
# 2009                            NaN    NaN    NaN    NaN
# 2010                            NaN    NaN    NaN    NaN
# 2011                            NaN    NaN   1/28    NaN
# 2012                            NaN    NaN   1/28    NaN
# 2013                            NaN    NaN   1/28    NaN
# 2014                            NaN    NaN   1/28    NaN
# 2015                            NaN    NaN   1/28    NaN
# 2016                            NaN    NaN   1/28    NaN
# 2017                            NaN    NaN   2/28    NaN
# 2018                            NaN    NaN    NaN    NaN
# 2019                            NaN    NaN    NaN   1/32
# 2020                            NaN    NaN    NaN   3/32
# ----------------------------------------------- #
# Crop type: Millet (Finger)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   1971A2 1998A2 2003A2 2018A2
# year
# 1983                           4/24    NaN    NaN    NaN
# 1984                           5/24    NaN    NaN    NaN
# 1985                           6/24    NaN    NaN    NaN
# 1986                           5/24    NaN    NaN    NaN
# 1987                           6/24    NaN    NaN    NaN
# 1988                           6/24    NaN    NaN    NaN
# 1989                           7/24    NaN    NaN    NaN
# 1990                           7/24    NaN    NaN    NaN
# 1991                           7/24    NaN    NaN    NaN
# 1992                           6/24    NaN    NaN    NaN
# 1993                           7/24    NaN    NaN    NaN
# 1994                           8/24    NaN    NaN    NaN
# 1995                           8/24    NaN    NaN    NaN
# 1996                           8/24    NaN    NaN    NaN
# 1997                           8/24    NaN    NaN    NaN
# 1998                            NaN   8/27    NaN    NaN
# 1999                            NaN   8/27    NaN    NaN
# 2000                            NaN   8/27    NaN    NaN
# 2001                            NaN   9/27    NaN    NaN
# 2002                            NaN   9/27    NaN    NaN
# 2003                            NaN    NaN  10/28    NaN
# 2004                            NaN    NaN  20/28    NaN
# 2005                            NaN    NaN  21/28    NaN
# 2006                            NaN    NaN  21/28    NaN
# 2007                            NaN    NaN  21/28    NaN
# 2008                            NaN    NaN  19/28    NaN
# 2009                            NaN    NaN  22/28    NaN
# 2010                            NaN    NaN  22/28    NaN
# 2011                            NaN    NaN  22/28    NaN
# 2012                            NaN    NaN  22/28    NaN
# 2013                            NaN    NaN  20/28    NaN
# 2014                            NaN    NaN  21/28    NaN
# 2015                            NaN    NaN  20/28    NaN
# 2016                            NaN    NaN  18/28    NaN
# 2017                            NaN    NaN  17/28    NaN
# 2018                            NaN    NaN    NaN  20/32
# 2019                            NaN    NaN    NaN  17/32
# 2020                            NaN    NaN    NaN  16/32
# ----------------------------------------------- #
# Crop type: Millet (Pearl)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   1971A2 1998A2 2003A2 2018A2
# year
# 1997                           1/24    NaN    NaN    NaN
# 1998                            NaN   1/27    NaN    NaN
# 1999                            NaN   1/27    NaN    NaN
# 2000                            NaN   1/27    NaN    NaN
# 2001                            NaN   1/27    NaN    NaN
# 2002                            NaN   1/27    NaN    NaN
# 2003                            NaN    NaN    NaN    NaN
# 2004                            NaN    NaN   8/28    NaN
# 2005                            NaN    NaN   6/28    NaN
# 2006                            NaN    NaN   8/28    NaN
# 2007                            NaN    NaN   9/28    NaN
# 2008                            NaN    NaN   9/28    NaN
# 2009                            NaN    NaN   9/28    NaN
# 2010                            NaN    NaN   9/28    NaN
# 2011                            NaN    NaN  10/28    NaN
# 2012                            NaN    NaN  10/28    NaN
# 2013                            NaN    NaN  10/28    NaN
# 2014                            NaN    NaN  10/28    NaN
# 2015                            NaN    NaN   9/28    NaN
# 2016                            NaN    NaN   8/28    NaN
# 2017                            NaN    NaN  10/28    NaN
# 2018                            NaN    NaN    NaN   8/32
# 2019                            NaN    NaN    NaN  11/32
# 2020                            NaN    NaN    NaN   7/32
# ----------------------------------------------- #
# Crop type: Onions
# ----------------------------------------------- #
# season_name                    Main           Winter
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2003A2 2018A2
# year
# 2017                           4/28    NaN      4/28    NaN
# 2018                            NaN    NaN       NaN    NaN
# 2019                            NaN   4/32       NaN   4/32
# ----------------------------------------------- #
# Crop type: Paprika (unspecified)
# ----------------------------------------------- #
# season_name                    Main           Winter
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2003A2 2018A2
# year
# 2004                          14/28    NaN       NaN    NaN
# 2005                          14/28    NaN       NaN    NaN
# 2006                          17/28    NaN       NaN    NaN
# 2007                          17/28    NaN      1/28    NaN
# 2008                          16/28    NaN      1/28    NaN
# 2009                          16/28    NaN      2/28    NaN
# 2010                          15/28    NaN      2/28    NaN
# 2011                          13/28    NaN      4/28    NaN
# 2012                          11/28    NaN      1/28    NaN
# 2013                          10/28    NaN      3/28    NaN
# 2014                           8/28    NaN      2/28    NaN
# 2015                          10/28    NaN      2/28    NaN
# 2016                           9/28    NaN      2/28    NaN
# 2017                           8/28    NaN      3/28    NaN
# 2018                            NaN   5/32       NaN   1/32
# 2019                            NaN   5/32       NaN   2/32
# 2020                            NaN   8/32       NaN   2/32
# ----------------------------------------------- #
# Crop type: Pigeon Peas
# ----------------------------------------------- #
# season_name                    Main                     Winter
# crop_production_system Rainfed (PS)        irrigated irrigated
# fnid_short                   2003A2 2018A2    2018A2    2003A2
# year
# 2004                          17/28    NaN       NaN       NaN
# 2005                          19/28    NaN       NaN       NaN
# 2006                          22/28    NaN       NaN       NaN
# 2007                          21/28    NaN       NaN       NaN
# 2008                          23/28    NaN       NaN       NaN
# 2009                          21/28    NaN       NaN       NaN
# 2010                          23/28    NaN       NaN       NaN
# 2011                          22/28    NaN       NaN       NaN
# 2012                          23/28    NaN       NaN       NaN
# 2013                          23/28    NaN       NaN       NaN
# 2014                          24/28    NaN       NaN       NaN
# 2015                          23/28    NaN       NaN       NaN
# 2016                          22/28    NaN       NaN       NaN
# 2017                          24/28    NaN       NaN      1/28
# 2018                            NaN  22/32      1/32       NaN
# 2019                            NaN  21/32       NaN       NaN
# 2020                            NaN  20/32       NaN       NaN
# ----------------------------------------------- #
# Crop type: Potato (Irish)
# ----------------------------------------------- #
# season_name                    Main                     Winter
# crop_production_system Rainfed (PS)        irrigated irrigated
# fnid_short                   2003A2 2018A2    2018A2    2003A2 2018A2
# year
# 2004                          13/28    NaN       NaN       NaN    NaN
# 2005                          13/28    NaN       NaN       NaN    NaN
# 2006                          18/28    NaN       NaN     14/28    NaN
# 2007                          16/28    NaN       NaN     11/28    NaN
# 2008                          18/28    NaN       NaN     11/28    NaN
# 2009                          17/28    NaN       NaN     14/28    NaN
# 2010                          19/28    NaN       NaN     17/28    NaN
# 2011                          19/28    NaN       NaN     18/28    NaN
# 2012                          19/28    NaN       NaN     18/28    NaN
# 2013                          19/28    NaN       NaN     19/28    NaN
# 2014                          19/28    NaN       NaN     19/28    NaN
# 2015                          19/28    NaN       NaN     19/28    NaN
# 2016                          19/28    NaN       NaN     19/28    NaN
# 2017                          17/28    NaN       NaN     18/28    NaN
# 2018                            NaN  16/32      1/32       NaN  12/32
# 2019                            NaN  17/32       NaN       NaN  16/32
# 2020                            NaN  17/32       NaN       NaN  16/32
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name              Annual         Main
# crop_production_system All (PS) Rainfed (PS)
# fnid_short               2018A2       1971A2 1998A2 2003A2 2018A2
# year
# 1986                        NaN         9/24   1/27    NaN    NaN
# 1987                        NaN        11/24   1/27    NaN    NaN
# 1988                        NaN        12/24   2/27    NaN    NaN
# 1989                        NaN        12/24   2/27    NaN    NaN
# 1990                        NaN        12/24   2/27    NaN    NaN
# 1991                        NaN        11/24   2/27    NaN    NaN
# 1992                        NaN        12/24   2/27    NaN    NaN
# 1993                        NaN        11/24   2/27    NaN    NaN
# 1994                        NaN        12/24   2/27    NaN    NaN
# 1995                        NaN        14/24   2/27    NaN    NaN
# 1996                        NaN        14/24   2/27    NaN    NaN
# 1997                        NaN        15/24   2/27    NaN    NaN
# 1998                        NaN          NaN  17/27    NaN    NaN
# 1999                        NaN          NaN  19/27    NaN    NaN
# 2000                        NaN          NaN  19/27    NaN    NaN
# 2001                        NaN          NaN  21/27    NaN    NaN
# 2002                        NaN          NaN  23/27    NaN    NaN
# 2003                        NaN          NaN    NaN  22/28    NaN
# 2004                        NaN          NaN    NaN  24/28    NaN
# 2005                        NaN          NaN    NaN  24/28    NaN
# 2006                        NaN          NaN    NaN  27/28    NaN
# 2007                        NaN          NaN    NaN  23/28    NaN
# 2008                        NaN          NaN    NaN  26/28    NaN
# 2009                        NaN          NaN    NaN  26/28    NaN
# 2010                        NaN          NaN    NaN  25/28    NaN
# 2011                        NaN          NaN    NaN  25/28    NaN
# 2012                        NaN          NaN    NaN  25/28    NaN
# 2013                        NaN          NaN    NaN  26/28    NaN
# 2014                        NaN          NaN    NaN  26/28    NaN
# 2015                        NaN          NaN    NaN  26/28    NaN
# 2016                        NaN          NaN    NaN  25/28    NaN
# 2017                        NaN          NaN    NaN  25/28    NaN
# 2018                        NaN          NaN    NaN    NaN  18/32
# 2019                       9/32          NaN    NaN    NaN  18/32
# 2020                      11/32          NaN    NaN    NaN  18/32
# 2021                      27/32          NaN    NaN    NaN    NaN
# 2022                      27/32          NaN    NaN    NaN    NaN
# 2023                      18/32          NaN    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Sesame Seed
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   2003A2 2018A2
# year
# 2004                           8/28    NaN
# 2005                           8/28    NaN
# 2006                           8/28    NaN
# 2007                          11/28    NaN
# 2008                          11/28    NaN
# 2009                          11/28    NaN
# 2010                          13/28    NaN
# 2011                          11/28    NaN
# 2012                          10/28    NaN
# 2013                          10/28    NaN
# 2014                           9/28    NaN
# 2015                          11/28    NaN
# 2016                          11/28    NaN
# 2017                          10/28    NaN
# 2018                            NaN  10/32
# 2019                            NaN  11/32
# 2020                            NaN   6/32
# ----------------------------------------------- #
# Crop type: Sorghum
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)
# fnid_short                   1971A2 1998A2 2003A2 2018A2
# year
# 1983                          10/24   1/27    NaN    NaN
# 1984                          12/24   1/27    NaN    NaN
# 1985                          12/24   1/27    NaN    NaN
# 1986                          10/24   1/27    NaN    NaN
# 1987                          11/24   1/27    NaN    NaN
# 1988                          10/24   2/27    NaN    NaN
# 1989                          11/24   2/27    NaN    NaN
# 1990                          11/24   2/27    NaN    NaN
# 1991                          11/24   2/27    NaN    NaN
# 1992                          11/24   2/27    NaN    NaN
# 1993                          12/24   2/27    NaN    NaN
# 1994                          12/24   2/27    NaN    NaN
# 1995                          16/24   2/27    NaN    NaN
# 1996                          17/24   2/27    NaN    NaN
# 1997                          21/24   2/27    NaN    NaN
# 1998                            NaN  22/27    NaN    NaN
# 1999                            NaN  22/27    NaN    NaN
# 2000                            NaN  21/27    NaN    NaN
# 2001                            NaN  20/27    NaN    NaN
# 2002                            NaN  21/27    NaN    NaN
# 2003                            NaN    NaN  22/28    NaN
# 2004                            NaN    NaN  20/28    NaN
# 2005                            NaN    NaN  21/28    NaN
# 2006                            NaN    NaN  22/28    NaN
# 2007                            NaN    NaN  21/28    NaN
# 2008                            NaN    NaN  21/28    NaN
# 2009                            NaN    NaN  21/28    NaN
# 2010                            NaN    NaN  22/28    NaN
# 2011                            NaN    NaN  22/28    NaN
# 2012                            NaN    NaN  22/28    NaN
# 2013                            NaN    NaN  22/28    NaN
# 2014                            NaN    NaN  22/28    NaN
# 2015                            NaN    NaN  22/28    NaN
# 2016                            NaN    NaN  20/28    NaN
# 2017                            NaN    NaN  19/28    NaN
# 2018                            NaN    NaN    NaN  14/32
# 2019                            NaN    NaN    NaN  21/32
# 2020                            NaN    NaN    NaN  17/32
# ----------------------------------------------- #
# Crop type: Soybean (unspecified)
# ----------------------------------------------- #
# season_name              Annual         Main
# crop_production_system All (PS) Rainfed (PS)
# fnid_short               2018A2       2003A2 2018A2
# year
# 2004                        NaN        17/28    NaN
# 2005                        NaN        21/28    NaN
# 2006                        NaN        26/28    NaN
# 2007                        NaN        27/28    NaN
# 2008                        NaN        26/28    NaN
# 2009                        NaN        26/28    NaN
# 2010                        NaN        26/28    NaN
# 2011                        NaN        26/28    NaN
# 2012                        NaN        26/28    NaN
# 2013                        NaN        27/28    NaN
# 2014                        NaN        26/28    NaN
# 2015                        NaN        26/28    NaN
# 2016                        NaN        26/28    NaN
# 2017                        NaN        24/28    NaN
# 2018                        NaN          NaN  22/32
# 2019                       4/32          NaN  22/32
# 2020                       8/32          NaN  19/32
# 2021                      26/32          NaN    NaN
# 2022                      26/32          NaN    NaN
# 2023                      19/32          NaN    NaN
# ----------------------------------------------- #
# Crop type: Sunflower Seed
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                           9/28    NaN       NaN
# 2005                           8/28    NaN       NaN
# 2006                          12/28    NaN       NaN
# 2007                           8/28    NaN       NaN
# 2008                          13/28    NaN       NaN
# 2009                          12/28    NaN       NaN
# 2010                          13/28    NaN       NaN
# 2011                          13/28    NaN       NaN
# 2012                          13/28    NaN       NaN
# 2013                          14/28    NaN       NaN
# 2014                          14/28    NaN       NaN
# 2015                          16/28    NaN       NaN
# 2016                          15/28    NaN       NaN
# 2017                          15/28    NaN       NaN
# 2018                            NaN  13/32      1/32
# 2019                            NaN  16/32       NaN
# 2020                            NaN  11/32       NaN
# ----------------------------------------------- #
# Crop type: Sweet Potatoes
# ----------------------------------------------- #
# season_name                    Main                     Winter
# crop_production_system Rainfed (PS)        irrigated irrigated
# fnid_short                   2003A2 2018A2    2018A2    2003A2 2018A2
# year
# 2003                          24/28    NaN       NaN       NaN    NaN
# 2004                          24/28    NaN       NaN       NaN    NaN
# 2005                          25/28    NaN       NaN       NaN    NaN
# 2006                          27/28    NaN       NaN     25/28    NaN
# 2007                          27/28    NaN       NaN     21/28    NaN
# 2008                          28/28    NaN       NaN     22/28    NaN
# 2009                          28/28    NaN       NaN     27/28    NaN
# 2010                          28/28    NaN       NaN     27/28    NaN
# 2011                          28/28    NaN       NaN     27/28    NaN
# 2012                          28/28    NaN       NaN     27/28    NaN
# 2013                          28/28    NaN       NaN     27/28    NaN
# 2014                          28/28    NaN       NaN     27/28    NaN
# 2015                          28/28    NaN       NaN     27/28    NaN
# 2016                          27/28    NaN       NaN     26/28    NaN
# 2017                          26/28    NaN       NaN     27/28    NaN
# 2018                            NaN  24/32      1/32       NaN  22/32
# 2019                            NaN  24/32       NaN       NaN  24/32
# 2020                            NaN  23/32       NaN       NaN  23/32
# ----------------------------------------------- #
# Crop type: Tobacco (Burley)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                          26/28    NaN       NaN
# 2005                          23/28    NaN       NaN
# 2006                          24/28    NaN       NaN
# 2007                          24/28    NaN       NaN
# 2008                          26/28    NaN       NaN
# 2009                          25/28    NaN       NaN
# 2010                          26/28    NaN       NaN
# 2011                          26/28    NaN       NaN
# 2012                          25/28    NaN       NaN
# 2013                          25/28    NaN       NaN
# 2014                          24/28    NaN       NaN
# 2015                          24/28    NaN       NaN
# 2016                          24/28    NaN       NaN
# 2017                          21/28    NaN       NaN
# 2018                            NaN  19/32      1/32
# 2019                            NaN    NaN       NaN
# 2020                            NaN  18/32       NaN
# ----------------------------------------------- #
# Crop type: Tomato
# ----------------------------------------------- #
# season_name                    Main           Winter
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2003A2 2018A2
# year
# 2017                           4/28    NaN      4/28    NaN
# 2018                            NaN    NaN       NaN    NaN
# 2019                            NaN   4/32       NaN   4/32
# ----------------------------------------------- #
# Crop type: Velvet bean
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS)        irrigated
# fnid_short                   2003A2 2018A2    2018A2
# year
# 2004                           8/28    NaN       NaN
# 2005                           7/28    NaN       NaN
# 2006                           9/28    NaN       NaN
# 2007                           9/28    NaN       NaN
# 2008                           9/28    NaN       NaN
# 2009                           9/28    NaN       NaN
# 2010                          10/28    NaN       NaN
# 2011                           9/28    NaN       NaN
# 2012                           9/28    NaN       NaN
# 2013                           9/28    NaN       NaN
# 2014                           9/28    NaN       NaN
# 2015                          10/28    NaN       NaN
# 2016                          10/28    NaN       NaN
# 2017                           9/28    NaN       NaN
# 2018                            NaN  10/32      1/32
# 2019                            NaN  10/32       NaN
# 2020                            NaN   6/32       NaN
# ----------------------------------------------- #
# Crop type: Wheat Grain
# ----------------------------------------------- #
# season_name               Winter
# crop_production_system irrigated
# fnid_short                2003A2 2018A2
# year
# 2008                        1/28    NaN
# 2009                        1/28    NaN
# 2010                        2/28    NaN
# 2011                        1/28    NaN
# 2012                        2/28    NaN
# 2013                        4/28    NaN
# 2014                        1/28    NaN
# 2015                        3/28    NaN
# 2016                        2/28    NaN
# 2017                         NaN    NaN
# 2018                         NaN   1/32
# 2019                         NaN   1/32
# 2020                         NaN   1/32
# ----------------------------------------------- #
# ../figures/MW_admin_shapes.png is saved.

# %% [markdown]
# - Malawi crop seasonal calendar
#
# <img src="https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-malawi.png?itok=Vq_GZunP" width=900><br>
#
# <img src="../figures/crop_calendar/fao_malawi_crop_calendar.jpeg" width=900>
#
# - FDW data consists of `MW1971A2`, `MW1998A2`, `MW2003A2`, and `MW2018A2`.
#
# | Year | Admin-1 | # units  | Admin-2  | # units |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1971 | MW1971A1 | 3 | **`MW1971A2`** | 24 |
# | 1998 | MW1998A1 | 3 | **`MW1998A2`** | 27 |
# | 2003 | MW2003A1 | 3 | **`MW2003A2`** | 28 |
# | 2018 | MW2018A1 | 3 | **`MW2018A2`** | 32 |
#
# - Comparison between admin boundaries.
#
# <img src="../figures/MW_admin_shapes.png" width=900>
#
#
# - **`MW2018A2`** is used to represent current admin-level 2 crop data.
# - Malawi has two crop seasons: `Main` and `Winter` (from 2006).
# - Malawi has three crop production systems: `None`, `Estate (PS)`, and `estate`.

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = MW_Admin2_2018.copy().to_crs('epsg:4326')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #

# %%
# Link admin boundaries ------------------------- #
link_1971, over_1971 = FDW_PD_CreateAdminLink(MW_Admin2_1971, MW_Admin2_2018, 'ADMIN2', 'ADMIN2', prod, epsg)
link_1998, over_1998 = FDW_PD_CreateAdminLink(MW_Admin2_1998, MW_Admin2_2018, 'ADMIN2', 'ADMIN2', prod, epsg)
link_2003, over_2003 = FDW_PD_CreateAdminLink(MW_Admin2_2003, MW_Admin2_2018, 'ADMIN2', 'ADMIN2', prod, epsg)

# Crop specific ratios
link_ratio_1971 = FDW_PD_RatioAdminLink(link_1971, prod, over_1971, mdx_pss)
link_ratio_1998 = FDW_PD_RatioAdminLink(link_1998, prod, over_1998, mdx_pss)
link_ratio_2003 = FDW_PD_RatioAdminLink(link_2003, prod, over_2003, mdx_pss)
link_merged = [ link_ratio_1971, link_ratio_1998, link_ratio_2003]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=True)
# ----------------------------------------------- #
# Out:
# CBR is considered for 'MW1971A20206' as no record found in: ['MW2018A20105']
# CBR is considered for 'MW1971A20105' as no record found in: ['MW2018A20215']
# CBR is considered for 'MW1971A20305' as no record found in: ['MW2018A20320']
# CBR is considered for 'MW1998A20206' as no record found in: ['MW2018A20105']
# CBR is considered for 'MW1998A20105' as no record found in: ['MW2018A20215']
# CBR is considered for 'MW1998A20305' as no record found in: ['MW2018A20320']
# CBR is considered for 'MW2003A20206' as no record found in: ['MW2018A20105']
# CBR is considered for 'MW2003A20105' as no record found in: ['MW2018A20215']
# CBR is considered for 'MW2003A20305' as no record found in: ['MW2018A20320']

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]
# Final Processing ------------------------------ #
# Product name mapping
stack = product_name_mapping(stack, list_except=None)
# Calibration of crop calendar using External Season Calendar (ESC)
esc = pd.read_csv('../data/crop_calendar/external_season_calendar.csv')
stack, link_ratio = FDW_PD_CaliSeasonYear(stack, esc, link_ratio=None)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #

#define a QC flag field
# 0 = no flag
# 1 = outlier
stack['QC_flag'] = 0
# Out:
# All [country, season_name] are in the external season calendar.

# %% [markdown]
# ## Postprocessing outlier removal

# %%
from matplotlib import pyplot as plt

outliers = [
            # These first four have been fixed in the data
            #['MW2018A20313','Maize','Main',2003],
            #['MW2018A20205','Millet','Main',2011],
            #['MW2018A20208','Sorghum','Main',2004],
            #['MW2018A20305','Sorghum','Main',2001],
            ['MW2018A20319','Sorghum','Main',2002],
             ['MW2018A20330','Maize','Annual',2023],
             ['MW2018A20324','Sesame Seed','Main',2004],
             ['MW2018A20214','Sunflower Seed','Main',2018],
           ]
stack=stack.sort_values(by='harvest_year')

#first plot, then flag the values (yield, production and harvested area)
for iou in outliers:
    plt.figure()
    plt.title('Outlier in FNID: '+iou[0]+'\nfor '+iou[1]+' in the '+str(iou[3])+' '+iou[2]+' season')
    plt.ylabel('tons/ha')
    plt.plot(stack[(stack.fnid==iou[0])&(stack['product']==iou[1])&(stack.season_name==iou[2])&(stack.indicator=='yield')].harvest_year.values,
            stack[(stack.fnid==iou[0])&(stack['product']==iou[1])&(stack.season_name==iou[2])&(stack.indicator=='yield')].value.values,'-o')
    plt.plot(stack[(stack.fnid==iou[0])&(stack['product']==iou[1])&(stack.season_name==iou[2])&(stack.indicator=='yield')&(stack.harvest_year==iou[3])].harvest_year.values,
            stack[(stack.fnid==iou[0])&(stack['product']==iou[1])&(stack.season_name==iou[2])&(stack.indicator=='yield')&(stack.harvest_year==iou[3])].value.values,'D',markersize=10)
    stack.loc[((stack.fnid==iou[0])&(stack['product']==iou[1])&(stack.season_name==iou[2])&(stack.harvest_year==iou[3])),'QC_flag']=1

# %%
# Save data
fn_out = '../data/crop/adm_crop_production_MW.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
# Out:
# ../data/crop/adm_crop_production_MW.csv is saved.

# %% [markdown]
# ## Visualization of production data

# %%
# Bar chart of national grain production
country_iso, country_name = 'MW', 'Malawi'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name in ['Annual','Main','Winter']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/MW_bar_natgrainprod_Annual.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/MW_bar_natgrainprod_Main.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/MW_bar_natgrainprod_Winter.png is saved.

# %%
# Lineplot of Production-Area-Yield (PAY) time-series
country_iso, country_name = 'MW', 'Malawi'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Cassava','Annual'],
    ['Cassava','Main'],
    ['Maize','Annual'],
    ['Maize','Main'],
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
