# %% [markdown]
# # HarvestStat Data Profiling - Cameroon

# %%
import glob
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import retreive_fdw_data, save_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import product_name_mapping, FDW_PD_CaliSeasonYear, FDW_PD_MergeCropProductionSystem
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# %%
# Set loading parameters ------------------------ #
country_name = 'Cameroon'
country_iso2 = 'CM'
use_api_data = False
requires_authentication = False
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'epsg:32633' # Cameroon
fn_shapes = sorted(glob.glob(f"../data/shapefile/fewsnet/{country_iso2}_Admin?_????.shp"))
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
# PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# Load FDW data -------------------------------- #
df = retreive_fdw_data(country_name, country_iso2, use_api_data, requires_authentication)
# ----------------------------------------------- #
# Out:
# Data is loaded from the local file.
# ../data/crop_raw_data/adm_crop_data_raw_CM.csv is loaded.

# %%
# Manual Pre-processing before Sweeping --------- #
# 1. Default setting
# a.1) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# a.2) Early in the record the catch-all crop production system is 'all' rather than none. Make these to none-type
df.loc[df['crop_production_system'] == 'all', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'
# ----------------------------------------------- #
#Drop the hundreds of blank (nan) rows that are duplicates of rows that do have data
df = df[np.isfinite(df.value)]
df = df.dropna(subset=['admin_2'])

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# # FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([CM_Admin2_2008], axis=0)
PlotAdminShapes(shape_used, label=True)
# # ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 17,867
# Removed 1 "Missing Value" points
# 5,835/5,836 "Area Planted" points are retained.
# 6,214/6,214 "Quantity Produced" points are retained.
# 5,817/5,817 "Yield" points are retained.
# Current data points: 17,866
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1998 - 2008
# 24 grain types are found: Bambara groundnut, Banana (unspecified), Beans (mixed), Cassava, Cooking Banana (unspecified), Cowpea (unspecified), Groundnuts (In Shell), Maize (Corn), Melon (unspecified), Millet, Okras (Fresh), Onions, Pam nut or kernal (unspecified), Pineapple (unspecified), Potato (Irish), Rice (Paddy), Sesame Seed, Soybean (unspecified), Squash and Melon seeds, Sweet Potatoes, Taro (move to 1594AA), Tomato, Watermelon, Yams
# 5 seasons are found: Annual (12-01), North 1st Season (11-01), North 2nd Season (12-01), 1st Season (10-01), 2nd Season (12-01)
# 1 crop production system are found: none
# Data sources include:
# [1] Ministere de l'agriculture, DEPA/CES, Cameroun --- Official agricultural statistics, Cameroon
# Administrative-1 fnids: 0
# Administrative-2 fnids: 58
# 0 reporting units are found:
#
# - Total production over time ------------------ #
# season_name                     1st Season 2nd Season Annual North 1st Season  \
#
# Bambara groundnut                     0.0%       0.0%   0.0%             0.0%
# Banana (unspecified)                  0.0%       0.0%   2.8%             0.0%
# Beans (mixed)                         0.8%       0.3%   0.2%             0.7%
# Cassava                               0.0%       0.0%  26.2%             0.0%
# Cooking Banana (unspecified)          0.0%       0.0%  18.7%             0.0%
# Cowpea (unspecified)                  0.0%       0.0%   0.0%             0.0%
# Groundnuts (In Shell)                 1.0%       0.2%   0.1%             1.2%
# Maize (Corn)                          4.4%       0.5%   0.4%             4.3%
# Melon (unspecified)                   0.0%       0.0%   0.1%             0.0%
# Millet                                0.0%       0.0%   0.5%             3.3%
# Okras (Fresh)                         0.0%       0.0%   0.4%             0.0%
# Onions                                0.0%       0.0%   0.1%             0.0%
# Pam nut or kernal (unspecified)       0.0%       0.0%   2.3%             0.0%
# Pineapple (unspecified)               0.0%       0.0%   0.5%             0.0%
# Potato (Irish)                        1.0%       0.2%   0.1%             0.0%
# Rice (Paddy)                          0.1%       0.1%   0.1%             0.4%
# Sesame Seed                           0.0%       0.0%   0.0%             0.0%
# Soybean (unspecified)                 0.1%       0.0%   0.0%             0.0%
# Squash and Melon seeds                0.8%       0.2%   0.0%             0.2%
# Sweet Potatoes                        0.7%       0.5%   0.2%             0.6%
# Taro (move to 1594AA)                 0.0%       0.0%  17.1%             0.0%
# Tomato                                0.9%       1.6%   0.1%             0.0%
# Watermelon                            0.0%       0.1%   0.1%             0.0%
# Yams                                  0.0%       0.0%   4.2%             0.0%
#
# season_name                     North 2nd Season
#
# Bambara groundnut                           0.0%
# Banana (unspecified)                        0.0%
# Beans (mixed)                               0.0%
# Cassava                                     0.0%
# Cooking Banana (unspecified)                0.0%
# Cowpea (unspecified)                        0.0%
# Groundnuts (In Shell)                       0.0%
# Maize (Corn)                                0.0%
# Melon (unspecified)                         0.0%
# Millet                                      1.1%
# Okras (Fresh)                               0.0%
# Onions                                      0.1%
# Pam nut or kernal (unspecified)             0.0%
# Pineapple (unspecified)                     0.0%
# Potato (Irish)                              0.0%
# Rice (Paddy)                                0.1%
# Sesame Seed                                 0.0%
# Soybean (unspecified)                       0.0%
# Squash and Melon seeds                      0.0%
# Sweet Potatoes                              0.1%
# Taro (move to 1594AA)                       0.0%
# Tomato                                      0.0%
# Watermelon                                  0.0%
# Yams                                        0.0%
#
# - Crop calendar ------------------------------- #
#                  product       season_name planting_month harvest_month
# 0      Bambara groundnut        1st Season          10-01         10-01
# 1      Bambara groundnut        2nd Season          12-01         12-01
# 2      Bambara groundnut            Annual          12-01         12-01
# 3   Banana (unspecified)            Annual          12-01         12-01
# 4          Beans (mixed)  North 1st Season          11-01         11-01
# ..                   ...               ...            ...           ...
# 60                Tomato            Annual          12-01         12-01
# 61            Watermelon            Annual          12-01         12-01
# 62            Watermelon        1st Season          10-01         10-01
# 63            Watermelon        2nd Season          12-01         12-01
# 64                  Yams            Annual          12-01         12-01
#
# [65 rows x 4 columns]
#
# - Recorded years per season ------------------- #
# Annual: 11 years (1998-2008) (missing: 0 years)
# North 1st Season: 11 years (1998-2008) (missing: 0 years)
# North 2nd Season: 10 years (1999-2008) (missing: 0 years)
# 1st Season: 11 years (1998-2008) (missing: 0 years)
# 2nd Season: 11 years (1998-2008) (missing: 0 years)
#
# - Number of "Quantity Produced" data points --- #
# CM2008A2: 6,214 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Bambara groundnut
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual
# crop_production_system       none       none   none
# fnid_short                 2008A2     2008A2 2008A2
# year
# 1998                          NaN        NaN   3/58
# 1999                         1/58       1/58  10/58
# 2000                         1/58       1/58   9/58
# 2001                         1/58       1/58   3/58
# 2002                         1/58       1/58   3/58
# 2003                         1/58       1/58   3/58
# 2004                         1/58       1/58   3/58
# 2005                         1/58       1/58   3/58
# 2006                          NaN        NaN   4/58
# 2007                          NaN        NaN   4/58
# 2008                          NaN        NaN   4/58
# ----------------------------------------------- #
# Crop type: Banana (unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                    15/58
# 1999                    39/58
# 2000                     4/58
# 2001                     4/58
# 2002                     4/58
# 2003                     4/58
# 2004                     4/58
# 2005                     4/58
# 2006                     4/58
# 2007                     4/58
# 2008                     4/58
# ----------------------------------------------- #
# Crop type: Beans (mixed)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season North 2nd Season
# crop_production_system       none       none   none             none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2           2008A2
# year
# 1998                         2/58       1/58  19/58             8/58              NaN
# 1999                        23/58      19/58   1/58            11/58             1/58
# 2000                        25/58      20/58   1/58            13/58             1/58
# 2001                        25/58      20/58   1/58            13/58             1/58
# 2002                        25/58      20/58   1/58            12/58             1/58
# 2003                        25/58      20/58   1/58            12/58             1/58
# 2004                        25/58      20/58   1/58            12/58             1/58
# 2005                        15/58       8/58   2/58            12/58             1/58
# 2006                         7/58        NaN   2/58            11/58              NaN
# 2007                         7/58        NaN   2/58            11/58              NaN
# 2008                         7/58        NaN   2/58            11/58              NaN
# ----------------------------------------------- #
# Crop type: Cassava
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                    46/58
# 1999                    35/58
# 2000                    40/58
# 2001                    40/58
# 2002                    40/58
# 2003                    40/58
# 2004                    40/58
# 2005                    41/58
# 2006                    41/58
# 2007                    41/58
# 2008                    45/58
# ----------------------------------------------- #
# Crop type: Cooking Banana (unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                    26/58
# 1999                    31/58
# 2000                    36/58
# 2001                    32/58
# 2002                    36/58
# 2003                    36/58
# 2004                    36/58
# 2005                    34/58
# 2006                    36/58
# 2007                    31/58
# 2008                    31/58
# ----------------------------------------------- #
# Crop type: Cowpea (unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 2001                     2/58
# 2002                     1/58
# 2003                     1/58
# 2004                     1/58
# 2005                     2/58
# 2006                     2/58
# 2007                     2/58
# 2008                     2/58
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season
# crop_production_system       none       none   none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2
# year
# 1998                        14/58       1/58  24/58             9/58
# 1999                        40/58      24/58    NaN             9/58
# 2000                        41/58      25/58    NaN            10/58
# 2001                        41/58      25/58    NaN            10/58
# 2002                        41/58      25/58    NaN            10/58
# 2003                        41/58      25/58    NaN            10/58
# 2004                        41/58      25/58    NaN            10/58
# 2005                        18/58       2/58    NaN            10/58
# 2006                        17/58       1/58    NaN             9/58
# 2007                        17/58       1/58    NaN             9/58
# 2008                        17/58       1/58    NaN             9/58
# ----------------------------------------------- #
# Crop type: Maize (Corn)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season North 2nd Season
# crop_production_system       none       none   none             none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2           2008A2
# year
# 1998                         9/58       1/58  33/58            13/58              NaN
# 1999                        41/58      33/58    NaN            15/58             1/58
# 2000                        43/58      35/58    NaN            15/58             1/58
# 2001                        43/58      35/58    NaN            15/58             1/58
# 2002                        43/58      35/58    NaN            15/58             1/58
# 2003                        43/58      35/58    NaN            15/58             1/58
# 2004                        43/58      35/58    NaN            15/58             1/58
# 2005                        10/58       2/58    NaN            14/58              NaN
# 2006                         8/58        NaN    NaN            14/58              NaN
# 2007                         8/58        NaN    NaN            14/58              NaN
# 2008                         8/58        NaN    NaN            14/58              NaN
# ----------------------------------------------- #
# Crop type: Melon (unspecified)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual
# crop_production_system       none       none   none
# fnid_short                 2008A2     2008A2 2008A2
# year
# 1999                         1/58       1/58   3/58
# 2000                         1/58       1/58   3/58
# 2001                         1/58       1/58   1/58
# 2002                         1/58       1/58   1/58
# 2003                         1/58       1/58   1/58
# 2004                         1/58       1/58   1/58
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season North 2nd Season
# crop_production_system       none       none   none             none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2           2008A2
# year
# 1998                          NaN        NaN  10/58             2/58              NaN
# 1999                         2/58       1/58    NaN            11/58             9/58
# 2000                         2/58       1/58    NaN            12/58            10/58
# 2001                         2/58       1/58    NaN            12/58            10/58
# 2002                         2/58       1/58    NaN            12/58            10/58
# 2003                         2/58       1/58    NaN            12/58            10/58
# 2004                         2/58       1/58    NaN            12/58            10/58
# 2005                         1/58        NaN    NaN             2/58              NaN
# 2006                         1/58        NaN    NaN             2/58              NaN
# 2007                         1/58        NaN    NaN             2/58              NaN
# 2008                         1/58        NaN    NaN             2/58              NaN
# ----------------------------------------------- #
# Crop type: Okras (Fresh)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                     8/58
# 1999                    10/58
# 2000                     7/58
# 2001                     7/58
# 2002                    18/58
# 2003                    14/58
# 2004                    13/58
# 2005                    23/58
# 2006                    22/58
# 2007                    22/58
# 2008                    22/58
# ----------------------------------------------- #
# Crop type: Onions
# ----------------------------------------------- #
# season_name            Annual North 2nd Season
# crop_production_system   none             none
# fnid_short             2008A2           2008A2
# year
# 1998                     7/58              NaN
# 1999                      NaN             1/58
# 2000                      NaN             1/58
# 2001                      NaN             1/58
# 2002                      NaN             1/58
# 2003                      NaN             1/58
# 2004                      NaN             1/58
# 2005                      NaN             1/58
# 2006                      NaN             1/58
# 2007                      NaN             1/58
# 2008                      NaN             1/58
# ----------------------------------------------- #
# Crop type: Pam nut or kernal (unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                     5/58
# 1999                    31/58
# 2000                    22/58
# 2001                    23/58
# 2002                    32/58
# 2003                    33/58
# 2004                    33/58
# 2005                    26/58
# 2006                    26/58
# 2007                    26/58
# 2008                    26/58
# ----------------------------------------------- #
# Crop type: Pineapple (unspecified)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1999                     2/58
# 2000                     1/58
# 2001                     1/58
# 2002                     1/58
# 2003                     1/58
# 2004                     1/58
# 2005                     2/58
# 2006                     2/58
# 2007                     2/58
# 2008                     2/58
# ----------------------------------------------- #
# Crop type: Potato (Irish)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season
# crop_production_system       none       none   none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2
# year
# 1998                         2/58        NaN   9/58             1/58
# 1999                        13/58      12/58    NaN             2/58
# 2000                        15/58      12/58    NaN             2/58
# 2001                        14/58      12/58    NaN             2/58
# 2002                        15/58      12/58    NaN             2/58
# 2003                        15/58      12/58    NaN             2/58
# 2004                        15/58      12/58    NaN             2/58
# 2005                         5/58       2/58    NaN             3/58
# 2006                         5/58       1/58    NaN             3/58
# 2007                         5/58       1/58    NaN             3/58
# 2008                         5/58       1/58    NaN             3/58
# ----------------------------------------------- #
# Crop type: Rice (Paddy)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season North 2nd Season
# crop_production_system       none       none   none             none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2           2008A2
# year
# 1998                         1/58       2/58   6/58             1/58              NaN
# 1999                         8/58       6/58    NaN             8/58             2/58
# 2000                         8/58       5/58    NaN             9/58             2/58
# 2001                         9/58       5/58    NaN             9/58             2/58
# 2002                         9/58       6/58    NaN             9/58             2/58
# 2003                         9/58       6/58    NaN             9/58             2/58
# 2004                         9/58       6/58    NaN             9/58             2/58
# 2005                         4/58       2/58   2/58             8/58              NaN
# 2006                         4/58       2/58   2/58             9/58              NaN
# 2007                         5/58       2/58   2/58             9/58              NaN
# 2008                         5/58       2/58   2/58             9/58              NaN
# ----------------------------------------------- #
# Crop type: Sesame Seed
# ----------------------------------------------- #
# season_name            1st Season North 1st Season
# crop_production_system       none             none
# fnid_short                 2008A2           2008A2
# year
# 1999                         2/58             6/58
# 2000                         2/58             6/58
# 2001                         2/58             6/58
# 2002                         2/58             6/58
# 2003                         2/58             6/58
# 2004                         2/58             6/58
# 2005                         2/58             6/58
# 2006                         2/58             6/58
# 2007                        10/58             8/58
# 2008                        11/58             8/58
# ----------------------------------------------- #
# Crop type: Soybean (unspecified)
# ----------------------------------------------- #
# season_name            1st Season 2nd Season North 1st Season
# crop_production_system       none       none             none
# fnid_short                 2008A2     2008A2           2008A2
# year
# 1999                        17/58      15/58             1/58
# 2000                        17/58      15/58             1/58
# 2001                        17/58      15/58             1/58
# 2002                        23/58      15/58             2/58
# 2003                        23/58      15/58             2/58
# 2004                        23/58      15/58             2/58
# 2005                         9/58       1/58             2/58
# 2006                         9/58       1/58             2/58
# 2007                         9/58       1/58             2/58
# 2008                         9/58       1/58             2/58
# ----------------------------------------------- #
# Crop type: Squash and Melon seeds
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season
# crop_production_system       none       none   none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2
# year
# 2000                        27/58       7/58    NaN             4/58
# 2001                        27/58       7/58    NaN             4/58
# 2002                        28/58       7/58    NaN             6/58
# 2003                        28/58       7/58    NaN             6/58
# 2004                        28/58       7/58    NaN             6/58
# 2005                        21/58       1/58    NaN             6/58
# 2006                        21/58       1/58    NaN             6/58
# 2007                        21/58       1/58    NaN             6/58
# 2008                        16/58       1/58   1/58             6/58
# ----------------------------------------------- #
# Crop type: Sweet Potatoes
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual North 1st Season North 2nd Season
# crop_production_system       none       none   none             none             none
# fnid_short                 2008A2     2008A2 2008A2           2008A2           2008A2
# year
# 1998                         4/58       2/58  14/58             5/58              NaN
# 1999                        18/58      16/58    NaN            13/58             5/58
# 2000                        19/58      16/58    NaN            12/58             5/58
# 2001                        19/58      16/58    NaN            13/58             5/58
# 2002                        20/58      16/58    NaN            13/58             5/58
# 2003                        20/58      16/58    NaN            13/58             5/58
# 2004                        20/58      16/58    NaN            13/58             5/58
# 2005                        11/58       8/58   3/58             9/58             1/58
# 2006                        10/58       6/58   3/58             9/58             1/58
# 2007                        10/58       6/58   3/58             9/58             1/58
# 2008                        10/58       6/58   3/58             9/58             1/58
# ----------------------------------------------- #
# Crop type: Taro (move to 1594AA)
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                    35/58
# 1999                    49/58
# 2000                    50/58
# 2001                    48/58
# 2002                    50/58
# 2003                    50/58
# 2004                    50/58
# 2005                    51/58
# 2006                    51/58
# 2007                    51/58
# 2008                    51/58
# ----------------------------------------------- #
# Crop type: Tomato
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual
# crop_production_system       none       none   none
# fnid_short                 2008A2     2008A2 2008A2
# year
# 1998                          NaN        NaN  12/58
# 1999                        13/58      14/58    NaN
# 2000                        13/58      14/58    NaN
# 2001                        12/58      13/58    NaN
# 2002                        12/58      13/58    NaN
# 2003                        12/58      13/58    NaN
# 2004                        12/58      13/58    NaN
# 2005                          NaN       1/58   1/58
# 2006                          NaN       1/58   2/58
# 2007                          NaN       1/58   2/58
# 2008                          NaN       1/58   2/58
# ----------------------------------------------- #
# Crop type: Watermelon
# ----------------------------------------------- #
# season_name            1st Season 2nd Season Annual
# crop_production_system       none       none   none
# fnid_short                 2008A2     2008A2 2008A2
# year
# 1999                         1/58       1/58   5/58
# 2000                         1/58       1/58   5/58
# 2001                         1/58       1/58    NaN
# 2002                         1/58       1/58    NaN
# 2003                         1/58       1/58    NaN
# 2004                         1/58       1/58    NaN
# 2005                          NaN        NaN   2/58
# 2006                          NaN        NaN   2/58
# 2007                          NaN        NaN   2/58
# 2008                          NaN        NaN   2/58
# ----------------------------------------------- #
# Crop type: Yams
# ----------------------------------------------- #
# season_name            Annual
# crop_production_system   none
# fnid_short             2008A2
# year
# 1998                    31/58
# 1999                    38/58
# 2000                    38/58
# 2001                    38/58
# 2002                    36/58
# 2003                    37/58
# 2004                    37/58
# 2005                    48/58
# 2006                    49/58
# 2007                    45/58
# 2008                    49/58
# ----------------------------------------------- #
# ../figures/CM_admin_shapes.png is saved.

# %% [markdown]
# - Cameroon crop seasonal calendar
#
# <img src="https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-cameroon.png?itok=FlNQVtNG" width=900><br>
#
# <img src="https://ipad.fas.usda.gov/rssiws/al/crop_calendar/images/wafrica_cm_calendar.png" width=900>
#
# - comparison of boundaries
#
# <img src="../figures/CM_admin_shapes.png" width=900>
#
# - In Cameroon, basd on the FEWS NET data, there was one time of change in administrative units: 2018
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 2008	 | CM2008A1 | 10	| CM2008A2	| 58	|
# | 2018	 | CM2018A1 | 10	| CM2018A2	| 58	|
#
# - Here, we use **`CM2008A2`** to represent all admin-level 2 crop data because although there  is 2018 file, it doesn't appear to be used (e.g. no corresponding FNIDs)
# - At admin-level 2,three crops have five seasons`Annual`,`North 1st Season`,`North 2nd Season `,`1st Season` and  `2nd Season`.

# %%
# Define the latest shapefile ------------------- #
latest_level = 2
shape_latest = CM_Admin2_2008.copy().to_crs('epsg:32633')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #
# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()

# %%
# Link admin boundaries ------------------------- #
link_2008, over_2008 = FDW_PD_CreateAdminLink(CM_Admin2_2008,CM_Admin2_2008, 'ADMIN2', 'ADMIN2', prod, epsg)

# Crop specific ratios
link_ratio = FDW_PD_RatioAdminLink(link_2008, prod, over_2008, mdx_pss)

# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=False)
# ----------------------------------------------- #

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new
# ----------------------------------------------- #

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]
# ----------------------------------------------- #

# Final Processing ------------------------------ #
# Product name mapping
stack = product_name_mapping(stack, list_except=None)
# Calibration of crop calendar using External Season Calendar (ESC)
esc = pd.read_csv('../data/crop_calendar/external_season_calendar.csv')
stack, link_ratio = FDW_PD_CaliSeasonYear(stack, esc, link_ratio=None)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #

#define a QC flag field
# 0 = no flag
# 1 = outlier
stack['QC_flag'] = 0

# Save data
fn_out = '../data/crop/adm_crop_production_CM.csv'
stack.to_csv(fn_out); print(f'{fn_out} is saved.')
# Out:
# All [country, season_name] are in the external season calendar.
# ../data/crop/adm_crop_production_CM.csv is saved.

# %%
# Bar chart of national crop production
country_iso, country_name = 'CM', 'Cameroon'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name   in ['Annual','North 1st Season','North 2nd Season','1st Season','2nd Season']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/CM_bar_natgrainprod_Annual.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/CM_bar_natgrainprod_North 1st Season.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/CM_bar_natgrainprod_North 2nd Season.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/CM_bar_natgrainprod_1st Season.png is saved.
# /Users/dlee/harveststat-africa/notebook/tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/CM_bar_natgrainprod_2nd Season.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name = 'CM', 'Cameroon'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Cassava', 'Annual'],
    ['Maize', 'North 1st Season'],
    ['Millet', 'North 2nd Season'],
    ['Maize', '1st Season'],
    ['Sweet Potatoes', '2nd Season']
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
